# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\\Users\\Yaseen Khan\\Documents\\Data Sceince\\DL - GenAI Projects\\Customer_Support_System\\data\\flipkart_product_review.csv")

# %%
data.head()
# Out:
#          product_id                                      product_title  \
# 0  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 1  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 2  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 3  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 4  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
#
#    rating            summary  \
# 0       5  Terrific purchase
# 1       5  Terrific purchase
# 2       5             Super!
# 3       5             Super!
# 4       5  Terrific purchase
#
#                                               review
# 0  1-more flexible2-bass is very high3-sound clar...
# 1     Super sound and good looking I like that prize
# 2  Very much satisfied with the device at this pr...
# 3  Nice headphone, bass was very good and sound i...
# 4  Sound quality super battery backup super quali...

# %%
iterrow_data=data.head(3)

# %%
data.columns
# Out:
# Index(['product_id', 'product_title', 'rating', 'summary', 'review'], dtype='object')

# %%
data['review'][0] #We gonna keep it as main data, and create embedding of it
# Out:
# "1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that. Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you.. 8-no more wireless headphones are comparing with that headphones at this pric..."

# %%
data["rating"][:5]  #This variable we can keep it as Meta data
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: rating, dtype: int64

# %%
data["product_title"][:5]  ##This variable we can keep it as Meta data
# Out:
# 0    BoAt Rockerz 235v2 with ASAP charging Version ...
# 1    BoAt Rockerz 235v2 with ASAP charging Version ...
# 2    BoAt Rockerz 235v2 with ASAP charging Version ...
# 3    BoAt Rockerz 235v2 with ASAP charging Version ...
# 4    BoAt Rockerz 235v2 with ASAP charging Version ...
# Name: product_title, dtype: object

# %%
data["summary"][:5]  ##This variable we can keep it as Meta data
# Out:
# 0    Terrific purchase
# 1    Terrific purchase
# 2               Super!
# 3               Super!
# 4    Terrific purchase
# Name: summary, dtype: object

# %%
#In the main data except this Product ID we have to keep all the columns

# %%
 for index,row in data.iterrows():
    print(index,row)
# Out:
# 0 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review           1-more flexible2-bass is very high3-sound clar...
# Name: 0, dtype: object
# 1 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review              Super sound and good looking I like that prize
# Name: 1, dtype: object
# 2 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# ...

# %%
# The iterrows() function in Python is used with Pandas DataFrames to iterate over the rows of the DataFrame, returning each row as a tuple containing:

# The index of the row.

# A Pandas Series representing the row’s data.

# %%
#Understanding iterrow() function
for index,row in iterrow_data.iterrows():
    print(index,row)

#Samaj ga
# Out:
# 0 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review           1-more flexible2-bass is very high3-sound clar...
# Name: 0, dtype: object
# 1 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review              Super sound and good looking I like that prize
# Name: 1, dtype: object
# 2 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# ...

# %%
product_list = []

for index,row in iterrow_data.iterrows():   #_ we are getting index, we don't need it

    # print(index,row)
    
    product_entry = {
        "product_title": row["product_title"],
        "rating": row["rating"],
        "summary": row["summary"],
        "review": row["review"]
    }
    # Append the product entry to the list
    product_list.append(product_entry)

print(product_list)
# Out:
# 0 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review           1-more flexible2-bass is very high3-sound clar...
# Name: 0, dtype: object
# 1 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# summary                                          Terrific purchase
# review              Super sound and good looking I like that prize
# Name: 1, dtype: object
# 2 product_id                                        ACCFZGAQJGYCYDCM
# product_title    BoAt Rockerz 235v2 with ASAP charging Version ...
# rating                                                           5
# ...
